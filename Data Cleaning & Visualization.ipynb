# %% [markdown]
# #Assignment 1
#
# Name: Lokesh Jeswani
# NU ID: 002795957

# %% [markdown]
# Abstract: The ability to foresee something's potential popularity is currently a crucial research area for all industries. It has recently grown in importance for the expanding and fiercely competitive music industry as well. Due to the widespread use of digital music platforms (such as Spotify, Billboard, and Tiktok), data may be quickly accessed and listener behavior can be easily tracked. This makes forecasting methods more convenient, and recommendation systems typically employ it as well.
#
# This model is fed the user data, and based on the user activity, rankings and recommendations are predicted, data is further trained to provide accurate and precise results.
#
# The below-mentioned notebook uses a variety of visualization approaches, such as the QQ plot, histogram, and box plot, to analyze the popularity of different numerical values. The study of the data shows that the model can forecast recommendations based on popularity properly, but there is still opportunity for improvement by utilizing more advanced machine learning approaches to obtain more detailed information.
#
# Dataset Description: TikTok start to get popularity in 2019 so it can be interesting to analyze what kind of music have been promoted by this social media and noticed by users.
# This dataset provides all important information that can be needed for further analyzation, starting from the basic knowledge such as track name and artist name, ending with the most advance stuff such as tempo, time_signature etc.

# %% [markdown]
# ##Dataset Features:

# %% [markdown]
# 1. Dataset consists of 223 records and has 18 features like tempo, liveliness, acousticness and speechness and various other tune characteristics.
# 2. Track_Popularity : Song rating based on the audience consumption of songs on the platform.
# 3. Dancability : Dancability describes how much the track is suitable for dance(more thumping beats) 0.0(least) - 1.0(highest).
# 4. Energy : Energy is again measured on the scale of 0.0 to 0.1 and represents the measure of energy in track(eg. fast and noisy).
# 5. loudness : the overall loudness of a track in decibels(-60 to 0 is the scale in detect the pitch of the tune).
# 6. Speechiness : speechiness indicated the vocal talk show (for eg: podcasts on streaming services) [Scale 0.33 to 0.66] - 0.33 is more likely music and no speech, less speech will indicate more intrumentalness and vice versa.
# 7. Acousticness : A measure from 0.0 to 1.0 of whether the track is acoustics, represents the feature of the song(if its acoustic or melodious).
# 8. Instrumentalness : no presence of vocals in the tune. (0.8 measure indicated the strong indication that the track is less vocals).
# 9. Liveliness : Detects the presence of audience (eg. concert).
# 10. Valence : measuring the positivity of music on the scale of 0.0 to 1.0[high valence indicated more positivity].
# 11. Tempo : Tempo of the track indicated the beats per minute(BPM), more the beats , more is the pace of music.
# 12. Time Signature : estimate duration of track.
# 13. duration_ms : duration of track in milliseconds

# %%
#importing all the important libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from matplotlib import pyplot

# %%
ttdata = pd.read_csv("https://raw.githubusercontent.com/Jeswani-Lokesh/DSEM---INFO6105/main/TikTok_songs_2019.csv")

# %%
ttdata.head()
# Out:
#              track_name                 artist_name  artist_pop  \
# 0              Shake It               Metro Station          53
# 1      Chinese New Year                       SALES          61
# 2        Baby I'm Yours                    Breakbot          57
# 3            The Git Up                Blanco Brown          60
# 4  Say Hey (I Love You)  Michael Franti & Spearhead          58
#
#                album  track_pop  danceability  energy  loudness  mode  key  \
# 0      Metro Station         68         0.618   0.955    -3.836     1    4
# 1         SALES - EP         53         0.744   0.845    -7.422     0    4
# 2       By Your Side         69         0.829   0.792    -3.755     0    2
# 3         The Git Up          2         0.847   0.678    -8.635     1    9
# 4  All Rebel Rockers          0         0.738   0.983    -4.374     0    5
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
ttdata.shape
# Out:
# (223, 18)

# %%
ttdata.isnull().sum()
# Out:
# track_name          0
# artist_name         0
# artist_pop          0
# album               0
# track_pop           0
# danceability        0
# energy              0
# loudness            0
# mode                0
# key                 0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# duration_ms         0
# dtype: int64

# %% [markdown]
# Q - Missing values present?
#
# ->  Dataset is complete and has no missing values.

# %% [markdown]
# Q - Which independent variables/column level data is missing?
#
# ->  No data is missing at the column level.

# %%
ttdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        223 non-null    object
#  1   artist_name       223 non-null    object
#  2   artist_pop        223 non-null    int64
#  3   album             223 non-null    object
#  4   track_pop         223 non-null    int64
#  5   danceability      223 non-null    float64
#  6   energy            223 non-null    float64
#  7   loudness          223 non-null    float64
#  8   mode              223 non-null    int64
#  9   key               223 non-null    int64
#  10  speechiness       223 non-null    float64
#  11  acousticness      223 non-null    float64
#  12  instrumentalness  223 non-null    float64
#  13  liveness          223 non-null    float64
#  14  valence           223 non-null    float64
#  15  tempo             223 non-null    float64
# ...

# %% [markdown]
# Q - What are the datatypes used?
#
# ->  Datatypes of the data in the dataset is categorized below:
#  * Categorical : track_name, artist_name, album
#  * Numerical : track_popularity, danceability, energy, loudness, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, duration_ms

# %%
from statsmodels.graphics.gofplots import qqplot
data_norm=ttdata[['track_pop', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'duration_ms']]
for c in data_norm.columns[:]:
  plt.figure(figsize=(8,5))
  fig=qqplot(data_norm[c],line='45',fit='True')
  plt.xticks(fontsize=13)
  plt.yticks(fontsize=13)
  plt.xlabel("Theoretical quantiles",fontsize=15)
  plt.ylabel("Sample quantiles",fontsize=15)
  plt.title("Q-Q plot of {}".format(c),fontsize=16)
  plt.grid(True)
  plt.show()

# %% [markdown]
# Q - What are the distribution of numerical values in dataset?
#
# -> Looking at the QQ plots, it signifies that the columns with numerical values follow the normal distribution pattern based on the data in it.

# %%
#Gives descriptive statistical results of various aggregate functions at column level
ttdata.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  223.000000  223.000000    223.000000  223.000000  223.000000
# mean    58.946188   50.192825      0.742673    0.607139   -7.381161
# std     18.124862   25.744474      0.140774    0.172197    3.134507
# min      0.000000    0.000000      0.247000    0.127000  -19.238000
# 25%     46.500000   42.500000      0.672000    0.475000   -8.799000
# 50%     61.000000   58.000000      0.749000    0.603000   -6.735000
# 75%     72.000000   69.000000      0.859000    0.736000   -5.114000
# max     93.000000   90.000000      0.978000    0.983000   -2.180000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  223.000000  223.000000   223.000000    223.000000        223.000000
# mean     0.650224    5.331839     0.149785      0.250346          0.033455
# std      0.477972    3.568786     0.141498      0.269444          0.137376
# ...

# %%
#calculates relationship between each column in the dataset
ttdata.corr()
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\1340078677.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ttdata.corr()
#                   artist_pop  track_pop  danceability    energy  loudness  \
# artist_pop          1.000000   0.371656     -0.130318  0.149147  0.306415
# track_pop           0.371656   1.000000     -0.128331  0.111767  0.228435
# danceability       -0.130318  -0.128331      1.000000 -0.073789  0.027604
# energy              0.149147   0.111767     -0.073789  1.000000  0.681296
# loudness            0.306415   0.228435      0.027604  0.681296  1.000000
# mode               -0.084856   0.028202     -0.032370 -0.113298 -0.128377
# key                 0.037813  -0.066201     -0.072175 -0.040515 -0.055901
# speechiness        -0.358864  -0.203603      0.368436 -0.116993 -0.079823
# ...

# %% [markdown]
# Q. Do the ranges of the predictor variable make sense?
# as ranges vary a lot, it does not make sense, we need to condider a mean value(mid-point) for contrasting results for easiness of visualization.

# %%
ttdata["popularity"]= [ 1 if a>=50 else 0 for a in ttdata.track_pop]
ttdata["popularity"].value_counts()
# Out:
# 1    152
# 0     71
# Name: popularity, dtype: int64

# %%
def bar_plot(variable):
    
    var=ttdata[variable]
    var_value= var.value_counts()
    
    plt.figure(figsize=(9,3))
    plt.bar(var_value.index,var_value,color="blue")
    plt.xticks(var_value.index,var_value.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}:\n{}".format(variable,var_value))

# %%
category = ["popularity","mode","key","time_signature"]
for a in category:
    bar_plot(a)
# Out:
# popularity:
# 1    152
# 0     71
# Name: popularity, dtype: int64
# mode:
# 1    145
# 0     78
# Name: mode, dtype: int64
# key:
# 1     34
# 7     29
# 11    20
# 4     19
# 8     19
# 2     18
# 0     18
# 5     17
# 10    17
# 9     13
# 6     13
# 3      6
# Name: key, dtype: int64
# time_signature:
# 4    214
# 3      5
# 5      3
# 1      1
# Name: time_signature, dtype: int64

# %% [markdown]
# #Checking popularity rating of songs that have been popular on the tiktok platform (year: 2019) and took the mean value of them : 50.
#  According to this value, the songs above this rating could remain on the top lists for a long time. If track_popularity is higher than 50 (this is about 30% percent of data) Thus, we have "1" for the most liked songs and "0" for the least liked.

# %%
#Gives descriptive stats of popular_tracks
popular_songs=ttdata[ttdata["popularity"]==1]
popular_songs.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  152.000000  152.000000    152.000000  152.000000  152.000000
# mean    63.690789   65.072368      0.734447    0.620651   -6.925368
# std     14.080296    9.648183      0.144775    0.167310    2.959639
# min     32.000000   50.000000      0.247000    0.127000  -19.238000
# 25%     55.000000   56.750000      0.662750    0.512750   -8.078750
# 50%     64.000000   64.000000      0.743000    0.621000   -6.241500
# 75%     75.000000   73.000000      0.849250    0.742750   -4.962250
# max     93.000000   90.000000      0.978000    0.955000   -2.180000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  152.000000  152.000000   152.000000    152.000000        152.000000
# mean     0.657895    5.375000     0.130655      0.239810          0.024366
# std      0.475983    3.541266     0.126758      0.262937          0.118828
# ...

# %%
f,ax = plt.subplots(figsize=(12, 12))
mask = np.zeros_like(ttdata.corr())
mask[np.triu_indices_from(mask)] = True
sns.heatmap(ttdata.corr(), annot=True, linewidths=0.4,linecolor="white", fmt= '.1f',ax=ax,cmap="Blues",mask=mask)
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\1819290423.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mask = np.zeros_like(ttdata.corr())
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\1819290423.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ttdata.corr(), annot=True, linewidths=0.4,linecolor="white", fmt= '.1f',ax=ax,cmap="Blues",mask=mask)

# %% [markdown]
# #As we see in the above shown heatmap - Correlation between loudness and energy is 0.7 (high)
# Correlation between speechness and danceability is 0.4(moderate)
# Acoustic and instrumentalness is 0.3(moderate)
# Correlation between loudness and acousticness is -0.6(least correaltion)
#
# As we can see, there is no strong correlation between song_popularity and other variables apart from artist_popularity.

# %%
#depicting ranking/popularity of song - keywise
ttdata[["key","popularity"]].groupby(["key"], as_index = False).mean().sort_values(by="popularity",ascending = False)
# Out:
#     key  popularity
# 0     0    0.833333
# 3     3    0.833333
# 7     7    0.758621
# 4     4    0.736842
# 2     2    0.722222
# 10   10    0.705882
# 6     6    0.692308
# 9     9    0.692308
# 11   11    0.650000
# 5     5    0.647059
# 8     8    0.631579
# 1     1    0.500000

# %%
#depicting ranking/popularity of song - audio-mode
ttdata[["mode","popularity"]].groupby(["mode"], as_index = False).mean().sort_values(by="popularity",ascending = False)
# Out:
#    mode  popularity
# 1     1    0.689655
# 0     0    0.666667

# %%
#Display the heatmap of dataset(displaying rationship between columns and rows)
plt.figure(figsize=(20,7))
sns.heatmap(ttdata.corr(), annot=True, cmap='RdYlGn')
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\3208362828.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ttdata.corr(), annot=True, cmap='RdYlGn')
# <AxesSubplot: >

# %%
sns.pairplot(ttdata)

# %% [markdown]
# Q. Are the predictor variables independent of all the other predictor variables?
#
# -> As we see in the above shown heatmap - Correlation between loudness and energy is 0.7 (high)
# Correlation between speechness and danceability is 0.4(moderate)
# Acoustic and instrumentalness is 0.3(moderate)
# Correlation between loudness and acousticness is -0.6(least correaltion)
#
# we dont see clear correlation between popularity and track characteristics(less correlation)

# %%
fig, ax = plt.subplots(figsize = (12, 10))
lead_artists =ttdata.groupby('artist_name')['track_pop'].sum().sort_values(ascending=False).head(10)
ax = sns.barplot(x=lead_artists.values, y=lead_artists.index, palette="Greens", orient="h", edgecolor='black', ax=ax)
ax.set_xlabel('Sum of Popularity', c='r', fontsize=12)
ax.set_ylabel('Artist', c='r', fontsize=12)
ax.set_title('10 Most Popular Artists in Dataset', c='r', fontsize=14, weight = 'bold')
plt.show()

# %%
def bar_plot(variable):
    
    var=ttdata[variable]
    var_value= var.value_counts()
    
    plt.figure(figsize=(15,3))
    plt.bar(var_value.index,var_value,color="blue")
    plt.xticks(var_value.index,var_value.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}:\n{}".format(variable,var_value))

# %%
category = ["artist_pop"]
for a in category:
    bar_plot(a)
# Out:
# artist_pop:
# 61    14
# 76     8
# 67     7
# 75     7
# 70     7
#       ..
# 36     1
# 16     1
# 80     1
# 37     1
# 11     1
# Name: artist_pop, Length: 68, dtype: int64

# %% [markdown]
# Since we believe there should be a correlation between the artist and the popularity of the track, we would like to use the Target Encoding approach, and replace the artist with some derivative of its popularity.
#
# First, we check distribution of number of times artists appear in the data.

# %%
# Adding Mean & Count values to each artist
ttdata['mean'] = ttdata.groupby('artist_name')['track_pop'].transform('mean')
ttdata['count'] = ttdata.groupby('artist_name')['track_pop'].transform('count')

fig, ax = plt.subplots(figsize = (10, 3))
ax = sns.distplot(ttdata['count'], bins = 600)
ax.set_xlabel('Count of apperances in data', fontsize=12, c='r')
ax.set_ylabel('% of artists', fontsize=12, c='r')
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\3355564027.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(ttdata['count'], bins = 600)

# %%
fig, ax = plt.subplots(figsize = (10, 5))
ax = sns.distplot(ttdata['count'], bins=600, kde=False)
ax.set_xlabel('Count of appearances in data', fontsize=12, c='r')
ax.set_ylabel('No. of artists', fontsize=12, c='r')
ax.set_xlim(1,20)
ax.set_xticks(range(1,21,1))
ax.axvline(x=2, ymin=0, ymax=1, color='orange', linestyle='dashed', linewidth=3)
font = {'family': 'serif',
        'color':  'red',
        'weight': 'bold',
        'size': 14,
        }
ax.annotate("", xy=(2, 250), xytext=(4.8, 250), arrowprops=dict(arrowstyle="->", color='r', linestyle='dashed', linewidth=3))
ax.text(x = 5, y = 250, s='cutoff = 2', fontdict=font)

plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\3140049519.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(ttdata['count'], bins=600, kde=False)

# %%
fig, ax = plt.subplots(figsize = (15, 3))
stat = ttdata.groupby('count')['mean'].mean().to_frame().reset_index()
ax = stat.plot(x='count', y='mean', marker='.', linestyle = '', ax=ax)
ax.set_xlabel('Count of appearances in data', fontsize=12, c='r')
ax.set_ylabel('Mean Popularity', fontsize=12, c='r')
plt.show()

# %%
frequent_flyer = ttdata[['artist_name','mean']].loc[ttdata['count']>1].value_counts(ascending=False).reset_index()
frequent_flyer.columns=['Artist','Mean Popularity', 'No. of Tracks']
frequent_flyer
# Out:
#                Artist  Mean Popularity  No. of Tracks
# 0                 SIX        63.333333              3
# 1           Ali Gatie        42.000000              2
# 2       Ariana Grande        33.000000              2
# 3            Doja Cat        75.500000              2
# 4                Jufu        28.500000              2
# 5               Kesha        66.500000              2
# 6           Lil Nas X        73.000000              2
# 7               Lizzo        51.500000              2
# 8        Mariah Carey        67.500000              2
# 9   Rex Orange County        76.000000              2
# 10       Taylor Swift        74.000000              2
# 11      Trevor Daniel         9.000000              2
# 12        iLOVEFRiDAY        45.500000              2

# %%
# mean popularity based on particular key
ttdata[["key","popularity"]].groupby(["key"], as_index = False).mean().sort_values(by="popularity",ascending = True)
# Out:
#     key  popularity
# 1     1    0.500000
# 8     8    0.631579
# 5     5    0.647059
# 11   11    0.650000
# 6     6    0.692308
# 9     9    0.692308
# 10   10    0.705882
# 2     2    0.722222
# 4     4    0.736842
# 7     7    0.758621
# 0     0    0.833333
# 3     3    0.833333

# %%
# popular tracks based on audio_mode
ttdata[["mode","popularity"]].groupby(["mode"], as_index = False).mean().sort_values(by="popularity",ascending = False)
# Out:
#    mode  popularity
# 1     1    0.689655
# 0     0    0.666667

# %%
ttdata[["time_signature","popularity"]].groupby(["time_signature"], as_index = False).mean().sort_values(by="popularity",ascending = False)
# Out:
#    time_signature  popularity
# 1               3    1.000000
# 2               4    0.677570
# 3               5    0.666667
# 0               1    0.000000

# %%
#calculating popularity probablity based on key
g = sns.catplot(x = "key", y = "popularity", data = ttdata, kind = "bar", height = 5)
g.set_ylabels("Popularity Probability")
plt.show()

# %%
#Popularity probablity based on audio_mode
g = sns.catplot(x = "mode", y = "popularity", data = ttdata, kind = "bar", height = 6)
g.set_ylabels("Popularity Probability")
plt.show()

# %%
#Popularity probablity based time_signature
g = sns.catplot(x = "time_signature", y = "popularity", data = ttdata, kind = "bar", height = 6)
g.set_ylabels("Popularity Probability")
plt.show()

# %% [markdown]
# #Popularity based on various Audio characteristics is depicted below with statistical data.

# %%
g = sns.FacetGrid(ttdata, row = "mode", col = "popularity", height = 4)
g.map(sns.barplot, "key", "acousticness")
g.add_legend()
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(ttdata, row = "mode", col = "popularity", height = 4)
g.map(sns.barplot, "key", "danceability",color="purple")
g.add_legend()
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(ttdata, row = "mode", col = "popularity", height = 4)
g.map(sns.barplot, "key", "instrumentalness",color="green")
g.add_legend()
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(ttdata, row = "mode", col = "popularity", height = 4)
g.map(sns.barplot, "loudness", "key",color="orange")
g.add_legend()
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
f, axes = plt.subplots(3, 5, figsize=(12, 12))
sns.histplot( ttdata["duration_ms"] , color="teal", ax=axes[0, 0])
sns.histplot( ttdata["instrumentalness"] , color="teal", ax=axes[0, 1])
sns.histplot( ttdata["acousticness"] , color="teal", ax=axes[0, 2])
sns.histplot( ttdata["danceability"] , color="teal", ax=axes[0, 3])
sns.histplot( ttdata["energy"] , color="teal", ax=axes[0, 4])
sns.histplot( ttdata["track_pop"] , color="teal", ax=axes[1, 0])
sns.histplot( ttdata["key"] , color="teal", ax=axes[1, 1])
sns.histplot( ttdata["liveness"] , color="teal", ax=axes[1, 2])
sns.histplot( ttdata["loudness"] , color="teal", ax=axes[1, 3])
sns.histplot( ttdata["mode"] , color="teal", ax=axes[1, 4])
sns.histplot( ttdata["tempo"] , color="teal", ax=axes[2, 0])
sns.histplot( ttdata["speechiness"] , color="teal", ax=axes[2, 1])
sns.histplot( ttdata["time_signature"] , color="teal", ax=axes[2, 2])
sns.histplot( ttdata["valence"] , color="teal", ax=axes[2, 3])
f.delaxes(axes[2][4])
plt.show()

# %%
g = sns.FacetGrid(ttdata, col = "popularity")
g.map(sns.histplot, "acousticness", bins = 25)
plt.show()

# %%
g = sns.FacetGrid(ttdata, col = "popularity")
g.map(sns.distplot, "danceability", bins = 25)
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
g = sns.FacetGrid(ttdata, col = "popularity")
g.map(sns.distplot, "loudness", bins = 25)
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
g = sns.FacetGrid(ttdata, col = "popularity")
g.map(sns.distplot, "instrumentalness", bins = 25)
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %% [markdown]
# - The distribution of song data shows that the danceability, intensity, loudness, and pace of today's songs are all extremely high. Fast and loud music is popular.
# - Most songs have lyrics and are not live performances, according to instrumentality, liveness, and speechness.
# - Songs that use keys like 3,7,10 and 11 tend to be more effective. The likelihood of a song becoming popular increases if the key is 0, 1, or 6.
# - The majority of Time signure in both populer and general data is 3 and 4.
# - A song has a greater probability of becoming popular if its danceability is greater than 0.6.
# - A song has a greater possibility of becoming popular if the loudness is greater than -7.

# %%
Music=ttdata.copy()
Music["valence"]= [ "Happy" if i>=0.5 else "Sad" for i in Music.valence ]
Music["valence"].value_counts()
# Out:
# Happy    141
# Sad       82
# Name: valence, dtype: int64

# %%
song_data=ttdata.copy()
song_data["valence"]= [ "Happy" if i>=0.5 else "Sad" for i in song_data.valence ]
song_data["valence"].value_counts()
# Out:
# Happy    141
# Sad       82
# Name: valence, dtype: int64

# %%
song_data2= song_data[song_data.popularity==1]
a=song_data2.iloc[:,1]
a.to_numpy()
b=song_data2.iloc[:,14]
b.to_numpy()
plt.figure(figsize=[8,8])
markerline, stemlines, baseline = plt.stem(
    a, b, linefmt='grey', markerfmt='D', bottom=0.5,use_line_collection= True)
markerline.set_markerfacecolor('none')
plt.ylabel("Popularity")
plt.xlabel("Audio Valance")
plt.show()
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_38584\2415679365.py:7: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   markerline, stemlines, baseline = plt.stem(
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Lokesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # Categorical EDA
# Q.(For Categorical Data):- What are the distributions of the predictor variables?
#
# Below are some distribution of categorical data

# %%
fig, ax = plt.subplots(figsize = (12, 10))
lead_artists =ttdata.groupby('artist_name')['track_pop'].sum().sort_values(ascending=False).head(10)
ax = sns.barplot(x=lead_artists.values, y=lead_artists.index, palette="Greens", orient="h", edgecolor='black', ax=ax)
ax.set_xlabel('Sum of Popularity', c='r', fontsize=12)
ax.set_ylabel('Artist', c='r', fontsize=12)
ax.set_title('10 Most Popular Artists in Dataset', c='r', fontsize=14, weight = 'bold')
plt.show()

# %%
ttdata['artist_pop'] = ttdata['artist_name'].map(ttdata['artist_name'].value_counts()>1)
pop_arts  = ttdata.groupby(['artist_name', 'artist_pop'])['track_pop'].mean().sort_values(ascending=False).reset_index(1)
df_pop_arts = pop_arts.loc[pop_arts['artist_pop'] == True,['track_pop']]

fig, ax = plt.subplots(figsize = (12, 10))
lead_artists = df_pop_arts.groupby('artist_name')['track_pop'].mean().sort_values(ascending=False).head(10)
ax = sns.barplot(x=lead_artists.values, y=lead_artists.index, palette="Greens", orient="h", edgecolor='black', ax=ax)
ax.set_xlabel('Mean of Popularity', c='r', fontsize=12)
ax.set_ylabel('Artist', c='r', fontsize=12)
ax.set_title('10 Most Popular Artists in Dataset with > 2 tracks', c='r', fontsize=14, weight = 'bold')
plt.show()

# %%
ttdata['track_name'].value_counts(dropna=False)
ttdata['track_name'].dropna(inplace=True)

# %%
import re
import nltk 
import nltk as nlp

nltk.download("stopwords") 
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')


from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lokesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lokesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Lokesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lokesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
track_name = [ word for word in ttdata.track_name if not word in set(stopwords.words("english"))]
lemma = nlp.WordNetLemmatizer()
track_name = [ lemma.lemmatize(word) for word in track_name]

# %%
track_name = [ word for word in song_data.track_name if not word in set(stopwords.words("english"))]
lemma = nlp.WordNetLemmatizer()
track_name = [ lemma.lemmatize(word) for word in track_name]

# %%
track_name_list = []
for track_name in ttdata.track_name:
    track_name = re.sub("[^a-zA-Z]"," ",track_name)
    track_name = track_name.lower() 
    track_name = nltk.word_tokenize(track_name)
    lemma = nlp.WordNetLemmatizer()
    track_name = [ lemma.lemmatize(word) for word in track_name]
    track_name = " ".join(track_name)
    track_name_list.append(track_name)

# %%
from sklearn.feature_extraction.text import CountVectorizer
max_features = 10
count_vectorizer = CountVectorizer(max_features=max_features,stop_words = "english")
sparce_matrix = count_vectorizer.fit_transform(track_name_list).toarray()

# %%
song_names=pd.DataFrame(track_name_list,columns=['Names'])
song_names
# Out:
#                      Names
# 0                 shake it
# 1         chinese new year
# 2           baby i m yours
# 3               the git up
# 4       say hey i love you
# ..                     ...
# 218   skinny legend anthem
# 219          material girl
# 220      i wish radio edit
# 221  oh no i got a disease
# 222                  woahh
#
# [223 rows x 1 columns]

# %%
from collections import Counter

# %%
artist= ttdata.artist_name.tolist()
name_count = Counter(artist)         
most_common_names2 = name_count.most_common(10) 
most_common_names2
# Out:
# [('SIX', 3),
#  ('Lil Nas X', 2),
#  ('iLOVEFRiDAY', 2),
#  ('Lizzo', 2),
#  ('Jufu', 2),
#  ('Ali Gatie', 2),
#  ('Ariana Grande', 2),
#  ('Rex Orange County', 2),
#  ('Trevor Daniel', 2),
#  ('Doja Cat', 2)]

# %% [markdown]
# #Modelling

# %%
ttdata
# Out:
#                 track_name                 artist_name  artist_pop  \
# 0                 Shake It               Metro Station       False
# 1         Chinese New Year                       SALES       False
# 2           Baby I'm Yours                    Breakbot       False
# 3               The Git Up                Blanco Brown       False
# 4     Say Hey (I Love You)  Michael Franti & Spearhead       False
# ..                     ...                         ...         ...
# 218   Skinny Legend Anthem                  Ava Louise       False
# 219          Material Girl                     Madonna       False
# 220    I Wish - Radio Edit                     Skee-Lo       False
# 221  Oh No I Got a Disease                   Buss Crew       False
# 222                  Woahh                        Jufu        True
#
#                                  album  track_pop  danceability  energy  \
# 0                        Metro Station         68         0.618   0.955
# ...

# %%
Music.drop(["track_pop","track_name","valence"],axis=1,inplace=True)

# %%
Music.columns[Music.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
def feature_scaling(ttdata):  # Function to scale all the features
    scaler = MinMaxScaler()
    scaler.fit(ttdata)
    scaled_df = scaler.transform(ttdata)
    scaled_df = pd.DataFrame(scaled_df, columns=ttdata.columns)
    return scaled_df

# %% [markdown]
# The data may now be visualized and interpreted with ease. From the boxplot shown above, the following can be deduced:
# Q.
# - Does it matter if outliers are eliminated or kept in the final prediction model?
# - Song duration ms, instrumentalness, liveness, speechiness, and pace have outliers, which means that most songs have instrumental music, are longer in length, and are more centered on the lyrics.
# It makes reasonable that only a small number of independent variable values are really large and far from zero.
#
# Since there are so many outliers, we could have to omit a sizable portion of the data, which could mean data loss and lead to inaccurate evaluation measures.

# %% [markdown]
# # Respond to the following inquiries.
# Which independent variables help forecast the target (dependent variable)?
#
#
# - A: The order of the dependent variables is given below.
#
# Acousticity, Audio Valence, Song Duration in Milliseconds, Loudness, Instrumentality, Liveliness, and Danceability
# tempo, key, audio mode, speechiness, intensity, and time signature
#
# Which of the independent variables lacks data? The amount?
# - A: There are no zeros or missing values for any independent variables.
#
# #Are the data in the training and test sets identical?
#
# Yes, some of the data from the test and the training are the same.
#
# # Are the predictor variables separate from one another in every way?
#
# They are not independent of one another, thus no. The correlation table and pairplot map both demonstrate that many of the independent variables are multi-collinear.
#
# # What are the most crucial predictor variables?

# %% [markdown]
# # Final Verdict
# Prior to adding the polarity of song name texts, we first attempted to forecast the popularity of songs using auditory features. Additionally, we fitted the model using a threshold for each importance. Even though acousticness is the most crucial of these criteria, it did not produce a convincing outcome.
# 200+ songs were on hand. RF produced the best results when compared to Decision Tree algorithms, which often perform better when there is less data. Since our data did not show any significant linear relationships, linear modeling was not successful. The gradient descent method was used to build the model in LR, and the best outcome after 200 iterations was a moderate one. Like many studies on popularity,
